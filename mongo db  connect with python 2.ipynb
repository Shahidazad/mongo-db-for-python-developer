# %%
from pymongo import MongoClient

# %%
uri="mongodb+srv://shahidazad:S9822469692%40a@cluster0.xebh8.mongodb.net/test"

# %%
client=MongoClient(uri)

# %%
m220=client.m220
movies=m220.movies

# %%
client.stats
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.xebh8.mongodb.net:27017', 'cluster0-shard-00-01.xebh8.mongodb.net:27017', 'cluster0-shard-00-00.xebh8.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-8ydyyl-shard-0', tls=True), 'stats')

# %%
client.list_database_names()
# Out:
# ['sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
sample_mflix=client.sample_mflix
mflix.list_collection_names()
# Out:
# ['theaters', 'users', 'comments', 'movies', 'sessions']

# %%
a=client['sample_airbnb']
a.list_collection_names()
# Out:
# ['listingsAndReviews']

# %%
movies=sample_mflix.movies

# %%
movies.count_documents({})
# Out:
# 23530

# %%
movies.find_one()
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4135'),
#  'plot': 'Three men hammer on an anvil and pass a bottle of beer around.',
#  'genres': ['Short'],
#  'runtime': 1,
#  'cast': ['Charles Kayser', 'John Ott'],
#  'num_mflix_comments': 0,
#  'title': 'Blacksmith Scene',
#  'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.',
#  'countries': ['USA'],
#  'released': datetime.datetime(1893, 5, 9, 0, 0),
#  'directors': ['William K.L. Dickson'],
#  'rated': 'UNRATED',
#  'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  'lastupdated': '2015-08-26 00:03:50.133000000',
#  'year': 1893,
# ...

# %%
import pymongo

# %%
from bson.json_util import dumps

# %%
uri="mongodb+srv://shahidazad:S9822469692%40a@cluster0.xebh8.mongodb.net/test"

# %%
client=pymongo.MongoClient(uri)

# %%
m220=client.m220
movies=m220.sample_movies

# %%
limited_cursor=sample_mflix.movies.find(
{"directors":"Sam Raimi"},
{"_id":0,"title":1,"cast":1}).limit(2)

# %%
print(dumps(limited_cursor,indent=2))
# Out:
# [
#   {
#     "cast": [
#       "Bruce Campbell",
#       "Ellen Sandweiss",
#       "Richard DeManincor",
#       "Betsy Baker"
#     ],
#     "title": "The Evil Dead"
#   },
#   {
#     "title": "Evil Dead II",
#     "cast": [
#       "Bruce Campbell",
#       "Sarah Berry",
#       "Dan Hicks",
#       "Kassie Wesley DePaiva"
#     ]
#   }
# ]

# %%
pipeline=[
    {"$match":{"directors":"Sam Raimi"}},
    {"$project":{"_id":0,"title":1,"cast":1}},
    {"$limit":2}
]

# %%
l_g=sample_mflix.movies.aggregate(pipeline)
print(dumps(l_g,indent=2))
# Out:
# [
#   {
#     "cast": [
#       "Bruce Campbell",
#       "Ellen Sandweiss",
#       "Richard DeManincor",
#       "Betsy Baker"
#     ],
#     "title": "The Evil Dead"
#   },
#   {
#     "title": "Evil Dead II",
#     "cast": [
#       "Bruce Campbell",
#       "Sarah Berry",
#       "Dan Hicks",
#       "Kassie Wesley DePaiva"
#     ]
#   }
# ]

# %%
sor=sample_mflix.movies.find({"directors":"Sam Raimi"},{"_id":0,"title":1,"year":1}).sort("year",1)

# %%
sor

# %%
for i in sor:
    print(i)
# Out:
# {'title': 'The Evil Dead', 'year': 1981}
# {'year': 1987, 'title': 'Evil Dead II'}
# {'year': 1990, 'title': 'Darkman'}
# {'title': 'Army of Darkness', 'year': 1992}
# {'title': 'The Quick and the Dead', 'year': 1995}
# {'title': 'A Simple Plan', 'year': 1998}
# {'year': 1999, 'title': 'For Love of the Game'}
# {'title': 'The Gift', 'year': 2000}
# {'title': 'Spider-Man', 'year': 2002}
# {'year': 2004, 'title': 'Spider-Man 2'}
# {'year': 2007, 'title': 'Spider-Man 3'}
# {'year': 2009, 'title': 'Drag Me to Hell'}
# {'title': 'Oz the Great and Powerful', 'year': 2013}

# %%
print(dumps(sor,indent=2))
# Out:
# []

# %%
pipeline = [
    { "$match": { "directors": "Sam Raimi" } },
    { "$project": { "_id": 0, "title": 1, "cast": 1 } },
    { "$limit": 2 }
]
sot_ag=sample_mflix.movies.aggregate(pipeline)

# %%
for i in s: print(i)

# %%
print(dumps(sot_ag,indent=2))
# Out:
# [
#   {
#     "cast": [
#       "Bruce Campbell",
#       "Ellen Sandweiss",
#       "Richard DeManincor",
#       "Betsy Baker"
#     ],
#     "title": "The Evil Dead"
#   },
#   {
#     "title": "Evil Dead II",
#     "cast": [
#       "Bruce Campbell",
#       "Sarah Berry",
#       "Dan Hicks",
#       "Kassie Wesley DePaiva"
#     ]
#   }
# ]

# %%
pipeline = [
    { "$match": { "directors": "Sam Raimi" } },
    { "$project": { "_id": 0, "title": 1, "cast": 1 } },
    { "$count": "number" }
]
sot_ag=sample_mflix.movies.aggregate(pipeline)

# %%
print(dumps(sot_ag,indent=2))
# Out:
# [
#   {
#     "number": 13
#   }
# ]

# %%
from pymongo import ASCENDING,DESCENDING

# %%
s=sample_mflix.movies.find({ "directors": "Sam Raimi" },{"_id":0, "title": 1, "cast": 1 }).sort("year",-1)

# %%
for i in s: print(i)
# Out:
# {'cast': ['James Franco', 'Mila Kunis', 'Rachel Weisz', 'Michelle Williams'], 'title': 'Oz the Great and Powerful'}
# {'title': 'Drag Me to Hell', 'cast': ['Alison Lohman', 'Justin Long', 'Lorna Raver', 'Dileep Rao']}
# {'title': 'Spider-Man 3', 'cast': ['Tobey Maguire', 'Kirsten Dunst', 'James Franco', 'Thomas Haden Church']}
# {'title': 'Spider-Man 2', 'cast': ['Tobey Maguire', 'Kirsten Dunst', 'James Franco', 'Alfred Molina']}
# {'cast': ['Tobey Maguire', 'Willem Dafoe', 'Kirsten Dunst', 'James Franco'], 'title': 'Spider-Man'}
# {'cast': ['Cate Blanchett', 'Giovanni Ribisi', 'Keanu Reeves', 'Katie Holmes'], 'title': 'The Gift'}
# {'title': 'For Love of the Game', 'cast': ['Kevin Costner', 'Kelly Preston', 'John C. Reilly', 'Jena Malone']}
# {'cast': ['Bill Paxton', 'Bridget Fonda', 'Billy Bob Thornton', 'Brent Briscoe'], 'title': 'A Simple Plan'}
# {'cast': ['Sharon Stone', 'Gene Hackman', 'Russell Crowe', 'Leonardo DiCaprio'], 'title': 'The Quick and the Dead'}
# ...

# %%
print(dumps(s,indent=2))
# Out:
# []

# %%
db=client.sample_supplies

# %%
db.list_collection_names()
# Out:
# ['sales']

# %%
db.sales
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-02.xebh8.mongodb.net:27017', 'cluster0-shard-00-01.xebh8.mongodb.net:27017', 'cluster0-shard-00-00.xebh8.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-8ydyyl-shard-0', tls=True), 'sample_supplies'), 'sales')

# %%
sale=db.sales

# %%
for i in sale.find():
    print(i)
# Out:
# {'_id': ObjectId('5bd761dcae323e45a93ccfe8'), 'saleDate': datetime.datetime(2015, 3, 23, 21, 6, 49, 506000), 'items': [{'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': Decimal128('40.01'), 'quantity': 2}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': Decimal128('35.29'), 'quantity': 2}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': Decimal128('56.12'), 'quantity': 5}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': Decimal128('77.71'), 'quantity': 2}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': Decimal128('18.47'), 'quantity': 2}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': Decimal128('19.95'), 'quantity': 8}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': Decimal128('8.08'), 'quantity': 3}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': Decimal128('14.16'), 'quantity': 3}]
# ...

# %%
sale.find()

# %%
sale.insert_one({'title':100,"year":89})

# %%
right=sale.insert_one({'title':100,"year":89})

# %%
right.acknowledged
# Out:
# True

# %%
right.inserted_id  # object id which we have inserted
# Out:
# ObjectId('629afa5a0b29b61bf2c2b7d8')

# %%
sale.find_one({'_id':right.inserted_id})
# Out:
# {'_id': ObjectId('629afa5a0b29b61bf2c2b7d8'), 'title': 100, 'year': 89}

# %%
upsert=sale.update_one({"title":"fort"},{"$set":{"title":"fornite","year":2019}},upsert=True)

# %%
upsert.raw_result  # check update or modified is happens
# Out:
# {'n': 1,
#  'electionId': ObjectId('7fffffff0000000000000106'),
#  'opTime': {'ts': Timestamp(1654324279, 14), 't': 262},
#  'upserted': ObjectId('629afc372f5d251567fa80bc'),
#  'nModified': 0,
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1654324279, 14),
#   'signature': {'hash': b'\xed\xe5\xa8-\x17\x88\xd8,<v\xef\xfch\xed\x86\xcf3\x10`\xd4',
#    'keyId': 7040429564060762120}},
#  'operationTime': Timestamp(1654324279, 14),
#  'updatedExisting': False}

# %%
upt=sale.update_one({"title":"fort"},{"$set":{"title":"fornite","year":2019}})

# %%
upt.raw_result
# Out:
# {'n': 0,
#  'electionId': ObjectId('7fffffff0000000000000106'),
#  'opTime': {'ts': Timestamp(1654324586, 15), 't': 262},
#  'nModified': 0,
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1654324586, 15),
#   'signature': {'hash': b'Y\xe9\x81\xf3K\xff\xf2\x823\x03\x96\x8aRm\x8e\xb5\x87\x0e\xfa\xc3',
#    'keyId': 7040429564060762120}},
#  'operationTime': Timestamp(1654324586, 15),
#  'updatedExisting': False}

# %%
from faker import Faker

# %%
import random

# %%
Faker.seed(42)
random.seed(42)

# %%
mflix=client.sample_mflix

# %%
fake_users = mflix.fake_users
fake_users.drop()

# %%
def make_user(iter_count):
    account_type = "premium" if iter_count % 2 == 0 else "standard"
    return {
        "name": fake.name(),
        "address": fake.address(),
        "email": fake.email(),
        "age": random.randrange(18, 65),
        "favorite_colors": [fake.color_name(), fake.color_name(), fake.color_name()],
        "account_type": account_type
    }

# %%
to_insert=[make_user(i) for i in range(12)]

# %%
fake_users.insert_many(to_insert)

# %%
print(dumps(fake_users.find(),indent=2))
# Out:
# [
#   {
#     "_id": {
#       "$oid": "629b2f6e0b29b61bf2c2b7d9"
#     },
#     "name": "Allison Hill",
#     "address": "819 Johnson Course\nEast William, OH 26563",
#     "email": "lrobinson@example.com",
#     "age": 58,
#     "favorite_colors": [
#       "AntiqueWhite",
#       "DimGray",
#       "Peru"
#     ],
#     "account_type": "premium"
#   },
#   {
#     "_id": {
#       "$oid": "629b2f6e0b29b61bf2c2b7da"
#     },
#     "name": "Christopher Bernard",
#     "address": "1559 Roman Stream\nHerrerafurt, OH 38928",
#     "email": "barbara10@example.net",
#     "age": 25,
#     "favorite_colors": [
#       "Khaki",
#       "LightSteelBlue",
#       "Cyan"
#     ],
#     "account_type": "standard"
#   },
#   {
#     "_id": {
#       "$oid": "629b2f6e0b29b61bf2c2b7db"
#     },
#     "name": "Sharon James",
#     "address": "55341 Amanda Gardens Apt. 764\nLake Mark, WI 07832",
#     "email": "lydiatrujillo@example.com",
#     "age": 19,
#     "favorite_colors": [
# ...

# %%
fake_users.update_one({"name": "Kristine Garcia"},{"$inc":{"age":1}})

# %%
print(dumps(fake_users.find_one({"name": "Kristine Garcia"}),indent=2))
# Out:
# {
#   "_id": {
#     "$oid": "629b2f6e0b29b61bf2c2b7e4"
#   },
#   "name": "Kristine Garcia",
#   "address": "51354 Samuel Plains Suite 980\nSarahville, DC 35165",
#   "email": "prestonjulia@example.org",
#   "age": 56,
#   "favorite_colors": [
#     "LightPink",
#     "LightSkyBlue",
#     "HoneyDew"
#   ],
#   "account_type": "standard"
# }

# %%
fake_users.update_one({"name": "Kristine Garcia"},{"$push":{"favorite_colors":112}})  # in push command value is increse and field should be array

# %%
print(dumps(fake_users.find_one({"name": "Kristine Garcia"}),indent=2))
# Out:
# {
#   "_id": {
#     "$oid": "629b2f6e0b29b61bf2c2b7e4"
#   },
#   "name": "Kristine Garcia",
#   "address": "51354 Samuel Plains Suite 980\nSarahville, DC 35165",
#   "email": "prestonjulia@example.org",
#   "age": 56,
#   "favorite_colors": [
#     "LightPink",
#     "LightSkyBlue",
#     "HoneyDew",
#     112
#   ],
#   "account_type": "standard"
# }

# %%
print(dumps(fake_users.find({"account_type": "standard"}, { "_id": 0, "name": 1, "account_type": 1}), indent=2))
# Out:
# [
#   {
#     "name": "Christopher Bernard",
#     "account_type": "standard"
#   },
#   {
#     "name": "Latoya Robbins",
#     "account_type": "standard"
#   },
#   {
#     "name": "Sheila Evans",
#     "account_type": "standard"
#   },
#   {
#     "name": "David Caldwell",
#     "account_type": "standard"
#   },
#   {
#     "name": "Richard Gibson",
#     "account_type": "standard"
#   },
#   {
#     "name": "Kristine Garcia",
#     "account_type": "standard"
#   }
# ]

# %%
p=fake_users.find({"account_type": "standard"},{"$count":"num"})

# %%
u_r=fake_users.update_many({"account_type": "standard"},{"$set":{"account_type":"premium"}})

# %%
re=fake_users.find({"account_type": "standard"})

# %%
print(dumps(re,indent=2))
# Out:
# []

# %%
print(u_r.acknowledged, u_r.matched_count, u_r.modified_count, u_r.upserted_id)
# Out:
# True 0 0 None

# %%
new_or_updated_user = make_user(0)
u_r = fake_users.update_one({"email": new_or_updated_user["email"]}, {"$set": new_or_updated_user}, upsert=True) # if value is not there then add it (upsert is true)

# %%
print(dumps(fake_users.find_one({"email": new_or_updated_user["email"]}), indent=2))
# Out:
# {
#   "_id": {
#     "$oid": "629b39972f5d2515674c7dee"
#   },
#   "email": "davenportbrandi@example.org",
#   "account_type": "premium",
#   "address": "0164 Adam Trail Apt. 427\nHoffmanville, UT 20037",
#   "age": 19,
#   "favorite_colors": [
#     "Plum",
#     "DarkSalmon",
#     "BlueViolet"
#   ],
#   "name": "Christina Walters"
# }

# %%
print(u_r.acknowledged, u_r.matched_count, u_r.modified_count, u_r.upserted_id)
# Out:
# True 0 0 629b39972f5d2515674c7dee

# %%
fake_users.drop()

# %%
lessons=client.lessons # create data base

# %%
deletes=lessons.deletes # create collection

# %%
import random 
random.seed(42)
deletes.drop()
imr=deletes.insert_many([{"_id":var,'random_bool':random.choice([True,False])} for var in range(100)])

# %%
assert len(imr.inserted_ids)==100

# %%
list(deletes.find().limit(4))
# Out:
# [{'_id': 0, 'random_bool': True},
#  {'_id': 1, 'random_bool': True},
#  {'_id': 2, 'random_bool': False},
#  {'_id': 3, 'random_bool': True}]

# %%
dir(deletes)
# Out:
# ['_BaseObject__codec_options',
#  '_BaseObject__read_concern',
#  '_BaseObject__read_preference',
#  '_BaseObject__write_concern',
#  '_Collection__create',
#  '_Collection__create_indexes',
#  '_Collection__database',
#  '_Collection__find_and_modify',
#  '_Collection__full_name',
#  '_Collection__name',
#  '_Collection__write_response_codec_options',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aggregate',
# ...

# %%
type(deletes)
# Out:
# pymongo.collection.Collection

# %%
type(imr)
# Out:
# pymongo.results.InsertManyResult

# %%
dir(imr)
# Out:
# ['_InsertManyResult__inserted_ids',
#  '_WriteResult__acknowledged',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_raise_if_unacknowledged',
#  'acknowledged',
#  'inserted_ids']

# %%
dr=deletes.delete_one({"random_bool": True})

# %%
dr.deleted_count
# Out:
# 1

# %%
dir(dr)
# Out:
# ['_DeleteResult__raw_result',
#  '_WriteResult__acknowledged',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_raise_if_unacknowledged',
#  'acknowledged',
#  'deleted_count',
#  'raw_result']

# %%
dr.raw_result
# Out:
# {'n': 1,
#  'electionId': ObjectId('7fffffff0000000000000106'),
#  'opTime': {'ts': Timestamp(1654404198, 95), 't': 262},
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1654404198, 95),
#   'signature': {'hash': b"K#/\x98\x19'\x97f\x12\x04I5\x00\x9c\x0c\x04\x9e\x11[\x8d",
#    'keyId': 7040429564060762120}},
#  'operationTime': Timestamp(1654404198, 95)}

# %%
deletes.find_one({'_id':99})
# Out:
# {'_id': 99, 'random_bool': False}

# %%
deletes.delete_one({'_id':99})

# %%
deletes.find_one({'_id':99})

# %%
len(list(deletes.find({'random_bool':False})))   # count the  false random bool
# Out:
# 43

# %%
len(list(deletes.find({'random_bool':True})))
# Out:
# 55

# %%
deletes.delete_many({'random_bool':False}) #delete all false random bool

# %%
len(list(deletes.find({'random_bool':True})))
# Out:
# 55

# %%
len(list(deletes.find({'random_bool':False})))
# Out:
# 0

# %%
shipments=lessons.shipments

# %%
shipments.drop()

# %%
cities = [ "Atlanta", "New York", "Miami", "Chicago", "Los Angeles", "Seattle", "Dallas" ]
products = [ "shoes", "pants", "shirts", "hats", "socks" ]
quantities = [ 10, 20, 40, 80, 160, 320, 640, 1280, 2560 ]
docs = []

for truck_id in range(30):
    source = random.choice(cities)
    destination = random.choice([c for c in cities if c != source])
    product = random.choice(products)
    quantity = random.choice(quantities)
    
    doc = {
        "truck_id": truck_id,
        "source": source,
        "destination": destination,
        "product": product,
        "quantity": quantity
    }
    
    docs.append(doc)

# %%
shipments.insert_many(docs)

# %%
shipments.count_documents({})
# Out:
# 30

# %%
len(list(shipments.find()))
# Out:
# 30

# %%
shipments.find_one()
# Out:
# {'_id': ObjectId('629c4afe0b29b61bf2c2b7e5'),
#  'truck_id': 0,
#  'source': 'Los Angeles',
#  'destination': 'Miami',
#  'product': 'socks',
#  'quantity': 10}

# %%
shipments.create_index('truck_id',unique=True)  # truch_id 1 means that it is ascending order
# Out:
# 'truck_id_1'

# %%
doc = {
    "source": "New York",                          # truck id already exist
    "destination": "Atlanta",
    "truck_id": 4,
    "product": "socks",
    "quantity": 40
}

try:
    r=shipments.insert_one(doc)
    print(r.inserted_id)
except Exception as e:
    print(e)
# Out:
# E11000 duplicate key error collection: lessons.shipments index: truck_id_1 dup key: { truck_id: 4 }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'truck_id': 1}, 'keyValue': {'truck_id': 4}, 'errmsg': 'E11000 duplicate key error collection: lessons.shipments index: truck_id_1 dup key: { truck_id: 4 }'}

# %%
import string
trucks=lessons.trucks
trucks.drop()   # now u can use new values
trucks.insert_many([{'_id':i,'license':''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(7))} for i in range(50)])

# %%
trucks.count_documents({})
# Out:
# 50

# %%
trucks.find_one()
# Out:
# {'_id': 31, 'license': 'ZS9IM0Y'}

# %%
inventory=lessons.inventory   # new collection

# %%
inventory.drop()

# %%
fruits = [ "strawberries", "bananas", "apples" ]
for fruit in fruits:
    inventory.insert_one( { "type": fruit, "quantity": 100 } )
    
list(inventory.find())
# Out:
# [{'_id': ObjectId('629c53bf0b29b61bf2c2b804'),
#   'type': 'strawberries',
#   'quantity': 100},
#  {'_id': ObjectId('629c53bf0b29b61bf2c2b805'),
#   'type': 'bananas',
#   'quantity': 100},
#  {'_id': ObjectId('629c53bf0b29b61bf2c2b806'),
#   'type': 'apples',
#   'quantity': 100}]

# %%
try:
    with inventory.watch(full_document='updateLookup') as change_stream_cursor:
        for data_change in change_stream_cursor:
            print(data_change)
except exception as e:
    print(e)

# %%
import time
import random
fruits = [ "strawberries", "bananas", "apples" ]
quantities = [ -1, -2, -4, -8 ]

while True:
    random_fruit = random.choice(fruits)
    random_quantity = random.choice(quantities)
    inventory.update_one({'type':random_fruit,'$gt':10},{"$inc":{"quantity":random_quantity}})
    time.sleep(1)
